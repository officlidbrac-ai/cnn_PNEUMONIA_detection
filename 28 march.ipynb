# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics # evaluation of the model 
from sklearn.linear_model import LinearRegression # Regression model
from sklearn.model_selection import train_test_split # splitting the data

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\car_resale_prices.csv")

# %%
df.head()
# Out:
#                       full_name resale_price registered_year engine_capacity  \
# 0  2017 Maruti Baleno 1.2 Alpha         5.45            2017         1197 cc
# 1            2018 Tata Hexa XTA           10            2018         2179 cc
# 2   2015 Maruti Swift Dzire VXI          4.5            2015         1197 cc
# 3   2015 Maruti Swift Dzire VXI          4.5            2015         1197 cc
# 4    2009 Hyundai i10 Magna 1.1          1.6            2009         1086 cc
#
#                insurance transmission_type  kms_driven    owner_type  \
# 0  Third Party insurance            Manual  40,000 Kms   First Owner
# 1  Third Party insurance         Automatic  70,000 Kms   First Owner
# 2  Third Party insurance            Manual  70,000 Kms  Second Owner
# 3  Third Party insurance            Manual  70,000 Kms  Second Owner
# 4  Third Party insurance            Manual  80,000 Kms   First Owner
#
#   fuel_type  max_power  seats     mileage  body_type  city
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17446 entries, 0 to 17445
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          17446 non-null  object
#  1   resale_price       17446 non-null  object
#  2   registered_year    17377 non-null  object
#  3   engine_capacity    17432 non-null  object
#  4   insurance          17439 non-null  object
#  5   transmission_type  17446 non-null  object
#  6   kms_driven         17443 non-null  object
#  7   owner_type         17401 non-null  object
#  8   fuel_type          17446 non-null  object
#  9   max_power          17344 non-null  object
#  10  seats              17436 non-null  float64
#  11  mileage            16938 non-null  object
#  12  body_type          17446 non-null  object
#  13  city               17446 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 1.9+ MB

# %%
#objective_data=df.select_dtypes(include=["str"])
#numerical_data=df.select_dtypes(include=[np.number])

# %%
#objective_data.columns

# %%
#objective_data.head()

# %%
#objective_data["engine_capacity"]=objective_data["engine_capacity"].str.split(" ", expands=True)[0]

# %%
#objective_data["engine_capacity"]=pd.to_numeric(objective_data["engine_capacity"])

# %%
#objective_data.dtypes

# %%
#objective_data["insurance"]

# %%
# objective_data["transmission_type"]

# %%
objective_data["kms_driven"]=pd.to_numeric(objective_data["kms_driven"].str.split(" ", expand=True)[0].str.replace(","))

# %%
 objective_data["mileage"]=objective_data["mileage"].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
#objective_data["city"]

# %%
objective_data.drop(columns=["full_name"], inplace=true
